# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Declaring constants
HTTP_STATUS_OK = 200
HTTP_STATUS_NOT_FOUND = 404

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0          0           gotse delchev  41.5667   23.7333     78.73        58
# 1          1               papatowai -46.5619  169.4708     43.25        67
# 2          2  happy valley-goose bay  53.3168  -60.3315     57.51        82
# 3          3             west island -12.1568   96.8225     80.58        69
# 4          4          ribeira grande  38.5167  -28.7000     68.77        94
# ..       ...                     ...      ...       ...       ...       ...
# 576      576          porto murtinho -21.6989  -57.8825     68.95        69
# 577      577                valdivia -39.8142  -73.2459     51.89        96
# 578      578                 douglas  41.3000  -96.1670     69.10        80
# 579      579                    hami  42.8000   93.4500    100.94        10
# 580      580                    hola  51.5377   23.1902     59.18        81
#
#      Cloudiness  Wind Speed Country        Date
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
#%%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    size="Humidity",
    color="City",
    geo = True,
    tiles = "OSM"
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrowed_city_df = city_data_df.loc[(city_data_df["Max Temp"] <= 90) \
                                    & (city_data_df["Max Temp"] >= 70) \
                                    & (city_data_df["Wind Speed"] < 10)
                                    & (city_data_df["Cloudiness"] == 0)]

# Drop any rows with null values
narrowed_city_df = narrowed_city_df.dropna()
narrowed_city_df = narrowed_city_df.reset_index()

# Display sample data
narrowed_city_df
# Out:
#     index  City_ID                    City      Lat       Lng  Max Temp  \
# 0       0        0           gotse delchev  41.5667   23.7333     78.73
# 1      27       27                karditsa  39.3656   21.9217     81.99
# 2      40       40             gargalianoi  37.0667   21.6333     79.41
# 3      66       66                 pachino  36.7186   15.0907     84.96
# 4      74       74                  bethel  41.3712  -73.4140     72.64
# 5      78       78                  badger  64.8000 -147.5333     71.51
# 6      96       96                portland  45.5234 -122.6762     73.06
# 7     105      105              winnemucca  40.9730 -117.7357     78.33
# 8     135      135             gulf shores  30.2460  -87.7008     85.05
# 9     190      190                benghazi  32.1167   20.0667     82.72
# 10    193      193               plainview  40.7765  -73.4673     75.45
# 11    213      213  saint-mandrier-sur-mer  43.0780    5.9290     76.86
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrowed_city_df.loc[:, ("City", "Country", "Lat", "Lng", "Humidity")]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# 0            gotse delchev      BG  41.5667   23.7333        58
# 1                 karditsa      GR  39.3656   21.9217        32
# 2              gargalianoi      GR  37.0667   21.6333        46
# 3                  pachino      IT  36.7186   15.0907        53
# 4                   bethel      US  41.3712  -73.4140        85
# 5                   badger      US  64.8000 -147.5333        74
# 6                 portland      US  45.5234 -122.6762        65
# 7               winnemucca      US  40.9730 -117.7357         8
# 8              gulf shores      US  30.2460  -87.7008        76
# 9                 benghazi      LY  32.1167   20.0667        65
# 10               plainview      US  40.7765  -73.4673        88
# 11  saint-mandrier-sur-mer      FR  43.0780    5.9290        70
# 12                  laguna      US  38.4210 -121.4238        52
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories" : "accommodation.hotel",
    "apiKey" : geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row["Lng"]
    lat = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    response = requests.get(base_url, params=params)
    status_code = response.status_code
    
    # check the validity of status code of the response
    if status_code == HTTP_STATUS_OK:
        # Convert the API response to JSON format
        name_address = response.json()
        # Grab the first hotel from the results and store the name in the hotel_df DataFrame
        try:
            hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
            # Log the search results
            print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
        except (KeyError, IndexError):
            # If no hotel is found, set the hotel name as "No hotel found".
            hotel_df.loc[index, "Hotel Name"] = "No hotel found"
            print(f"{hotel_df.loc[index, 'City']} - No hotel found (KeyError, IndexError)")
    elif status_code == HTTP_STATUS_NOT_FOUND:
            # If no hotel is found, set the hotel name as "No hotel found".
            hotel_df.loc[index, "Hotel Name"] = "No hotel found"
            print(f"{hotel_df.loc[index, 'City']} - No hotel found (404)")
    else:
        raise ValueError(f"Invalid status code:{status_code} for {row['City']}, {row['Country']}")
    
    
# Display sample data
hotel_df
# Out:
# Starting hotel search
# gotse delchev - No hotel found (KeyError, IndexError)
# karditsa - nearest hotel: Ξενοδοχείο
# gargalianoi - nearest hotel: Messinian Horizons
# pachino - nearest hotel: Hotel Celeste
# bethel - nearest hotel: Hampton Inn Danbury
# badger - nearest hotel: Hotel North Pole
# portland - nearest hotel: the Hoxton
# winnemucca - nearest hotel: The Overland Hotel
# gulf shores - nearest hotel: Beachside Resort
# benghazi - nearest hotel: ترجاب
# plainview - nearest hotel: Residence Inn by Marriott
# saint-mandrier-sur-mer - nearest hotel: Le Barock
# laguna - nearest hotel: Holiday Inn Express & Suites
# freeport - nearest hotel: The Freeport Inn and Marina
# tadmur - nearest hotel: فندق فيلا بالميرا
# xiva - nearest hotel: B&B Orzu
# westport - nearest hotel: Norwalk Inn and Conference Center
# beyneu - nearest hotel: Johan yu
# newman - No hotel found (KeyError, IndexError)
# at taj - No hotel found (KeyError, IndexError)
# ghat - nearest hotel: فندق تاسيلي
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#%%capture --no-display

# Configure the map plot
map_plot_final = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    size="Humidity",
    color="City",
    geo = True,
    tiles = "OSM",
    hover_cols=["Hotel Name", "Country"],
    frame_width=800,
    frame_height=500
)

# Display the map
map_plot_final
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
